# %%
import pandas as pd 
import os
from csvToJSON import data_months
import numpy as np

print data_months

dataset = data_months[1]

datapath = os.path.join(os.path.abspath('.'), 'data/%s.csv' % dataset)
df = pd.read_csv(datapath)
df_subset = df.ix[0:99]
df.to_json("%s_100rows.json" % dataset)

print datapath
df_subset
# Out:
# ['CitiBikeJulySept2014', 'CitiBikeFebruary2014']
# /home/greenteawarrior/CitiBike/data/CitiBikeFebruary2014.csv
#     tripduration            starttime             stoptime  start station id  \
# 0            382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
# 1            372  2014-02-01 00:00:03  2014-02-01 00:06:15               285
# 2            591  2014-02-01 00:00:09  2014-02-01 00:10:00               247
# 3            583  2014-02-01 00:00:32  2014-02-01 00:10:15               357
# 4            223  2014-02-01 00:00:41  2014-02-01 00:04:24               401
# 5            541  2014-02-01 00:00:46  2014-02-01 00:09:47               152
# 6            354  2014-02-01 00:01:01  2014-02-01 00:06:55               325
# 7            916  2014-02-01 00:01:11  2014-02-01 00:16:27               354
# 8            277  2014-02-01 00:01:33  2014-02-01 00:06:10               375
# 9            439  2014-02-01 00:02:14  2014-02-01 00:09:33               285
# ...
